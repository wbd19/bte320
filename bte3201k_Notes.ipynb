# %% [markdown]
# <a href="https://colab.research.google.com/github/wbd19/bte320/blob/main/bte3201k_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# This is a test

# %%
x = 2
x = 'b'
x = 3.14

# %%
type(x)
# Out:
# int

# %%
isinstance(x, (int, float, bool))
# Out:
# True

# %% [markdown]
# This is a another test

# %%
x = 2
x == 2
# Out:
# True

# %%
s = 'abc'

# %%
a == b
a < b
a <= b
a > b
a >= b
a != b

# %%
a+b

# %%
5 + 3.0
# Out:
# 8.0

# %%
5-4
# Out:
# 1

# %%
4*3
# Out:
# 12

# %%
6/4
# Out:
# 1.5

# %%
6 // 4
# Out:
# 1

# %%
6.0 // 4.0
# Out:
# 1.0

# %%
2 ** 3
# Out:
# 8

# %%
6 % 3
# Out:
# 0

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
x = x + 1

x += 1

# %%
3 not in ...

# %%
name = 5
name4 = 6

4name = 7

studentLoan = ...
student_loan = ...

# %%
a = 3
b = 'abc'

# %%
a, b = 3, 'abc'
